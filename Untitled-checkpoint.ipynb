# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/danes/Downloads/archive/Uncleaned_DS_jobs.csv')

# %%
df = pd.DataFrame(df)

# %%
df = df[df['Job Title'].str.contains('Data')]

# %%
df
# Out:
#      index          Job Title               Salary Estimate  \
# 0        0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1        1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2        2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3        3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4        4     Data Scientist  $137K-$171K (Glassdoor est.)
# ..     ...                ...                           ...
# 667    667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668    668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669    669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670    670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671    671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# ...

# %%
df = df[df['Location']=='New York, NY']

# %%
df
# Out:
#      index                                    Job Title  \
# 0        0                            Sr Data Scientist
# 4        4                               Data Scientist
# 20      20                               Data Scientist
# 21      21              Data Scientist/Machine Learning
# 66      66                               Data Scientist
# 76      76          Data Engineer, Enterprise Analytics
# 78      78                               Data Scientist
# 97      97       Data Scientist, Kinship - NYC/Portland
# 115    115                               Data Scientist
# 173    173           Senior Data Scientist - Algorithms
# 182    182                        Sr. Data Scientist II
# 194    194         Senior Data Scientist - R&D Oncology
# 221    221              Data Scientist/Machine Learning
# 234    234                        Sr. Data Scientist II
# 242    242                       Software Data Engineer
# 253    253                               Data Scientist
# ...

# %%
grouped_df = df.groupby('Job Title')['Sector'].count()

# %%
grouped_df
# Out:
# Job Title
# Clinical Data Analyst                           1
# Data Engineer, Digital & Comp Pathology         1
# Data Engineer, Enterprise Analytics             1
# Data Scientist                                 28
# Data Scientist(s)/Machine Learning Engineer     2
# Data Scientist, Kinship - NYC/Portland          2
# Data Scientist/Machine Learning                 2
# Senior Data Engineer                            1
# Senior Data Scientist - Algorithms              1
# Senior Data Scientist - R&D Oncology            2
# Software Data Engineer                          1
# Sr Data Scientist                               1
# Sr. Data Scientist II                           2
# VP, Data Science                                2
# Name: Sector, dtype: int64

# %%
dfclean = pd.read_csv('C:/Users/danes/Downloads/archive/cleaned_DS_jobs.csv')

# %%
dfclean  = pd.DataFrame(dfclean)

# %%
dfclean
# Out:
#              Job Title Salary Estimate  \
# 0    Sr Data Scientist        137-171
# 1       Data Scientist        137-171
# 2       Data Scientist        137-171
# 3       Data Scientist        137-171
# 4       Data Scientist        137-171
# ..                 ...             ...
# 655     Data Scientist        105-167
# 656     Data Scientist        105-167
# 657     Data Scientist        105-167
# 658     Data Scientist        105-167
# 659     Data Scientist        105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# ...

# %%
dfclean = dfclean.merge(df, on = 'Company Name')

# %%
dfclean
# Out:
#       Job Title_x Salary Estimate_x  \
# 0  Data Scientist           145-225
# 1  Data Scientist           145-225
# 2  Data Scientist          124-198
# 3  Data Scientist          124-198
# 4  Data Scientist          212-331
#
#                                    Job Description_x  Rating_x  Company Name  \
# 0  Job Description\nSelecting features, building ...       0.0  Microagility
# 1  Job Description\nSelecting features, building ...       0.0  Microagility
# 2  Job Description\nSelecting features, building ...       0.0  Microagility
# 3  Job Description\nSelecting features, building ...       0.0  Microagility
# 4  CompuForce is seeking an experienced and highl...       0.0    CompuForce
#
#      Location_x Headquarters_x             Size_x Type of ownership_x  \
# 0  New York, NY  Princeton, NJ  1 to 50 employees   Company - Private
# 1  New York, NY  Princeton, NJ  1 to 50 employees   Company - Private
# 2  New York, NY  Princeton, NJ  1 to 50 employees   Company - Private
# ...
